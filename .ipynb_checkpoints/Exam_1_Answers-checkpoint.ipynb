# %% [markdown]
# # Exam 1 - Gema Castillo García

# %% [markdown]
# ## Problem 2
#
# Create a directory listing command that shows:
#
# * the ownership of the file
# * its file-size, in Megabytes (i.e. human readable)
#
# then:
#
# * in words (in a Markdown box), describe the _permissions_ on that file (read/write/execute) for users, groups, and "anyone"

# %%
ls -lh --author
# Out:
# total 1.5M
# -rw-rw-r-- 1 osboxes osboxes osboxes 260K Sep  6 14:01 Exam_1_Answers.ipynb
# -rw-rw-r-- 1 osboxes osboxes osboxes 1.1K Sep  6 13:12 LICENSE
# -rw-rw-r-- 1 osboxes osboxes osboxes 1.2M Sep  3 15:51 Locus_Germplasm_Phenotype_20130122.txt
# -rw-rw-r-- 1 osboxes osboxes osboxes   10 Sep  6 13:12 README.md

# %% [markdown]
# The first column shows the permissions on the files (I will explain it later) and the second one shows the number of hard links to these files (e.g., 1). Then, there are three columns that show the owner, group and author of the files, respectively. Finallly, there are the size and last modified date and time.
#
# --author shows the column of the authors and -h shows file-size in Megabytes (i.e. human readable). Therefore, the ownership of the Locus_Germplasm_Phenotype_20130122.txt file is osboxes and its file-size is 1.2 Mb.
#
#
# The column of permissions is structured like this: -/---/---/--- (file type/owner/groups/any user or program). Therefore, the permissions on the Locus_Germplasm_Phenotype_20130122.txt file are read (r) and write (w) for the owner and groups, and read (r) for anyone.

# %% [markdown]
# ## Problem 3
#
# * Create a command that outputs only the "header" line of Locus_Germplasm_Phenotype_20130122.txt

# %%
head -1 Locus_Germplasm_Phenotype_20130122.txt
# Out:
# Locus_name)	Germplasm_name	phenotype	pubmed_id

# %% [markdown]
# head outputs the first ten lines of files and with -1 it only outputs the first line (the header in this case).

# %% [markdown]
# ## Problem 4
#
# * Create a command that outputs the total number of lines in Locus_Germplasm_Phenotype_20130122.txt

# %%
wc -l Locus_Germplasm_Phenotype_20130122.txt
# Out:
# 7216 Locus_Germplasm_Phenotype_20130122.txt

# %% [markdown]
# wc prints newline, word, and byte counts for each file. wc -l only prints the newline counts (7216 lines in this case).

# %% [markdown]
# ## Problem 5
#
# * Create a command that writes ONLY the data lines (i.e. excludes the header!) to a new file called "Data_Only.csv"
# * prove that your output file has the expected number of lines

# %%
tail -7215 Locus_Germplasm_Phenotype_20130122.txt > Data_Only.csv
wc -l Data_Only.csv
# Out:
# 7215 Data_Only.csv

# %% [markdown]
# As the file has 7216 lines (see Problem 4) and the header is in the first line, you can select the last 7215 lines with tail.
#
#
# Using wc -l we can see that the new file has 7215 lines as expected.

# %% [markdown]
# ## Problem 6
#
# * Create a command that shows all of the lines that have a phenotype including the word "root"

# %%
grep "\sroot\s" -n Locus_Germplasm_Phenotype_20130122.txt
# Out:
# 23:AT1G01550	bps1-2	Growth of bps1-2 mutants on CPTA-supplemented medium resulted in partial rescue of both leaf and root defects. bps1-2 mutants grown on control growth medium have small radialized leaves with very little vascular tissue, and very short misshapen knotted-looking roots. By contrast, bps1-2 mutants grown on CPTA-supplemented medium produced larger flattened leaves that contained primary and secondary veins, and smooth elongated roots.	17217459
# 24:AT1G01550	bps1-2	Mutant roots were abnormal; primary and lateral roots were short, root hairs formed close to the root apex, and root defects were most severe when plants were grown at low temperature.	15458645
# ...

# %% [markdown]
# grep with -n prefixes each line of output with the 1-based line number within its input file to see all of the lines that have a phenotype including the word "root". I do not use -i because I do not want to ignore case distinctions.

# %% [markdown]
# ## Problem 7
#
# * Create a command that writes the AGI Locus Code for every line that has a phenotype including the word "root" to a file called: **Root-associated-Loci.txt**

# %%
grep "\sroot\s" -n Locus_Germplasm_Phenotype_20130122.txt | grep -iEo "AT[1-5]G[0-9]{5}" > Root-associated-Loci.txt

# %% [markdown]
# Using grep -o only prints the matched parts of a matching line. It allows to introduce all* the Locus Codes in a new file.
#
#
# *Although the last loci do not follow the AGI Locus Code, I have only searched for AGI Locus Codes as required by the Problem.

# %% [markdown]
# ## Problem 8
#
# * Create a command that writes the PubMed ID for every line that has a phenotype including the word "root" to a file called: **Root-associated-Publications.txt**

# %%
grep "\sroot\s" -n Locus_Germplasm_Phenotype_20130122.txt | grep -iEo "\s[0-9]+$" > Root-associated-Publications.txt

# %% [markdown]
# As PubMed IDs are all digits (0-9) and the length is unpredictable, I use $ because it points out the end of a line.

# %% [markdown]
# ## Problem 9
#
# * _**Control experiment**_:  You would hypothesize that genes associated with roots **should be found on all chromosomes.**  Find a way (one or more commands) to test this hypothesis.  In this dataset, is the hypothesis true?

# %%
echo "associated genes found on chromosome 1"
grep -iEo "AT[1]G[0-9]{5}" Root-associated-Loci.txt
echo "associated genes found on chromosome 2"
grep -iEo "AT[2]G[0-9]{5}" Root-associated-Loci.txt
echo "associated genes found on chromosome 3"
grep -iEo "AT[3]G[0-9]{5}" Root-associated-Loci.txt
echo "associated genes found on chromosome 4"
grep -iEo "AT[4]G[0-9]{5}" Root-associated-Loci.txt
echo "associated genes found on chromosome 5"
grep -iEo "AT[5]G[0-9]{5}" Root-associated-Loci.txt
# Out:
# associated genes found on chromosome 1
# AT1G01550
# AT1G01550
# AT1G01550
# AT1G02970
# AT1G03000
# AT1G03060
# AT1G03060
# AT1G03060
# AT1G03060
# AT1G04020
# AT1G04030
# AT1G04160
# AT1G04160
# AT1G04160
# AT1G04220
# AT1G04250
# AT1G05180
# AT1G05180
# AT1G05850
# AT1G05850
# AT1G06290
# AT1G06290
# AT1G08030
# AT1G08260
# AT1G08370
# AT1G08430
# AT1G09100
# AT1G09110
# AT1G10130
# AT1G10570
# AT1G11130
# AT1G15550
# AT1G15690
# AT1G16150
# AT1G17170
# AT1G17580
# AT1G17580
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G19220
# AT1G21700
# AT1G22920
# AT1G22920
# AT1G23010
# AT1G23010
# AT1G23310
# AT1G23320
# AT1G26870
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27320
# AT1G27760
# AT1G28560
# AT1G29990
# AT1G31880
# AT1G31880
# AT1G31880
# AT1G31880
# AT1G32450
# AT1G33280
# AT1G33280
# AT1G33290
# AT1G33290
# AT1G34370
# AT1G34370
# AT1G34370
# AT1G35580
# ...

# %% [markdown]
# In this dataset, the hypothesis is true because there are AGI Locus Codes of the five chromosomes.

# %% [markdown]
# ## Problem 10
#
# * If your control experiment shows genes on every chromosome, then you can skip this question!  (you answered Problem 9 correctly!)
#
# *  If your control experiment shows genes only on one or two chromosomes, then you have to explain why... what could the problem be?  (I told you specifically to be careful about this problem!)
